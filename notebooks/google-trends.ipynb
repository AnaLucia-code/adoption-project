# %%
import pandas as pd

# %%
from pytrends.request import TrendReq

# %%
pytrend = TrendReq()

# %%
kw_list=["Pet Adoption"]

# %%
pytrend.build_payload(kw_list=["Pet", "coronavirus"], geo = "US", timeframe = 'today 3-m')

# %%
df = pytrend.interest_by_region()

# %%
df
# Out:
#                       Pet  coronavirus
# geoName
# Alabama                 5           95
# Alaska                  4           96
# Arizona                 4           96
# Arkansas                4           96
# California              4           96
# Colorado                4           96
# Connecticut             4           96
# Delaware                4           96
# District of Columbia    2           98
# Florida                 5           95
# Georgia                 4           96
# Hawaii                  3           97
# Idaho                   4           96
# Illinois                4           96
# Indiana                 5           95
# Iowa                    4           96
# Kansas                  5           95
# Kentucky                5           95
# Louisiana               4           96
# Maine                   4           96
# Maryland                3           97
# Massachusetts           3           97
# Michigan                4           96
# ...

# %%
dframe.to_csv("trenddata.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e98c200ed0f0> in <module>
# ----> 1 dframe.to_csv("trenddata.csv")
#
# NameError: name 'dframe' is not defined
